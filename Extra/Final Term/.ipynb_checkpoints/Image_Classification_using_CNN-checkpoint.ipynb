# %% [markdown]
# [Sport Celebrity Image Classification](https://www.kaggle.com/datasets/yaswanthgali/sport-celebrity-image-classification)
#
# Data contain around 100 images of each celebrity namely Kobe, Kane, Maria, and Ronaldo.
#
#
# **Maria Sharapova:** Maria Yuryevna Sharapova is a Russian former world No. 1 tennis player.<br/>
# **Kobe Bryant:** Kobe Bean Bryant was an American professional basketball player.<br/>
# **Kane Williamson:** Kane Stuart Williamson is a New Zealand international cricketer who is currently the captain of the New Zealand national team in all formats.<br/>
# **Cristiano Ronaldo:** Cristiano Ronaldo is a Portuguese professional footballer.<br/>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/ComputerVision_Shared/CNN_Code/'
# Out:
# Image_Classification_using_CNN.ipynb  V2_Image_Classification_using_CNN.ipynb
# Sports_Celebrity_Data

# %%
dataset_path = '/content/drive/My Drive/ComputerVision_Shared/CNN_Code/Sports_Celebrity_Data/'

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# **Load the Data**

# %%
# lists to hold data

images = []
labels = []

# %%
# listing all folder names in the specified path
folders = os.listdir(dataset_path)
folders
# Out:
# ['Maria Sharapova', 'Kobe Bryant', 'Ronaldo', 'Kane Williamson']

# %%
# Creating dictionaries to map folder names

name_mapping_dict = {'Maria Sharapova': 0,
                     'Kobe Bryant': 1,
                     'Ronaldo': 2,
                     'Kane Williamson': 3}


inv_name_mapping_dict =  {v: k for k, v in name_mapping_dict.items()}

print(inv_name_mapping_dict)
# Out:
# {0: 'Maria Sharapova', 1: 'Kobe Bryant', 2: 'Ronaldo', 3: 'Kane Williamson'}

# %%
# Setting image size
img_size = 256

# %% [markdown]
# **Pre-process dataset**

# %%
# looping through each folder and getting images and creating labels
for folder in folders:
  print(f'Processing folder: {folder}')
  filenames = os.listdir(dataset_path+folder+'/')

  for fname in filenames:
    img = plt.imread(dataset_path+folder+'/'+fname)
    img = cv2.resize(img, (img_size, img_size))
    images.append(img)
    labels.append(name_mapping_dict[folder])
# Out:
# Processing folder: Maria Sharapova
# Processing folder: Kobe Bryant
# Processing folder: Ronaldo
# Processing folder: Kane Williamson

# %%
# Converting lists to numpy arrays for easy matrix operations
images = np.array(images)
labels = np.array(labels)

# %%
print('images shape : ', images.shape)
print('labels shape : ', labels.shape)
# Out:
# images shape :  (441, 256, 256, 3)
# labels shape :  (441,)

# %%
# Plotting samples from data to check if data has been read successfully
img_number = 65
plt.figure(figsize=[10,5])
plt.imshow(images[img_number,:,:])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[labels[img_number]]))
plt.show()

# %%
# Plotting samples from data to check if data has been read successfully
img_number = 207
plt.figure(figsize=[10,5])
plt.imshow(images[img_number,:,:])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[labels[img_number]]))
plt.show()

# %%
# Plotting samples from data to check if data has been read successfully
img_number = 306
plt.figure(figsize=[10,5])
plt.imshow(images[img_number,:,:])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[labels[img_number]]))
plt.show()

# %%
# Plotting samples from data to check if data has been read successfully
img_number = 406
plt.figure(figsize=[10,5])
plt.imshow(images[img_number,:,:])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[labels[img_number]]))
plt.show()

# %%
# Find the unique numbers from the train labels
classes = np.unique(labels)
classes_num = len(classes)
print('Total number of outputs : ', classes_num)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  4
# Output classes :  [0 1 2 3]

# %%
# Normalize training image pixels
images = np.array(images) / 255

# %%
# Change the labels from integer to categorical data
labels_one_hot = to_categorical(labels)

# %%
labels[303]
# Out:
# 2

# %%
labels_one_hot[303]
# Out:
# array([0., 0., 1., 0.], dtype=float32)

# %% [markdown]
# **Shuffling and Splittng Dataset**

# %%
# Shuffling and Splittng Dataset
from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(images, labels_one_hot, test_size=0.10, shuffle=True, random_state=0)


print('Training data shape : ', train_images.shape, train_labels.shape)
print('Testing data shape : ', test_images.shape, test_labels.shape)
# Out:
# Training data shape :  (396, 256, 256, 3) (396, 4)
# Testing data shape :  (45, 256, 256, 3) (45, 4)

# %% [markdown]
# **Design the Network Architecure for Convolutional Neural Network**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten 

# Same padding: This padding ensures that the output layer has the same size as the input layer
model = Sequential()
model.add(Conv2D(32, 3, padding="same", activation="relu", input_shape=(img_size, img_size, 3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(classes_num, activation="softmax"))

# %% [markdown]
# **Configure the model training time parameters**

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Train the Model**

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=15, verbose=1, 
                   validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 4/4 [==============================] - 33s 7s/step - loss: 2.4117 - accuracy: 0.2273 - val_loss: 2.0047 - val_accuracy: 0.2000
# Epoch 2/15
# 4/4 [==============================] - 30s 7s/step - loss: 1.5587 - accuracy: 0.3182 - val_loss: 1.3317 - val_accuracy: 0.3778
# Epoch 3/15
# 4/4 [==============================] - 30s 7s/step - loss: 1.2672 - accuracy: 0.4419 - val_loss: 1.2228 - val_accuracy: 0.5778
# Epoch 4/15
# 4/4 [==============================] - 30s 7s/step - loss: 1.1275 - accuracy: 0.5657 - val_loss: 1.0989 - val_accuracy: 0.5333
# Epoch 5/15
# 4/4 [==============================] - 32s 8s/step - loss: 0.9933 - accuracy: 0.5682 - val_loss: 1.2401 - val_accuracy: 0.4222
# Epoch 6/15
# 4/4 [==============================] - 30s 7s/step - loss: 1.0732 - accuracy: 0.5354 - val_loss: 1.2226 - val_accuracy: 0.5556
# Epoch 7/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.9631 - accuracy: 0.5758 - val_loss: 1.1741 - val_accuracy: 0.5778
# Epoch 8/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.8372 - accuracy: 0.7197 - val_loss: 1.1451 - val_accuracy: 0.5778
# Epoch 9/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.7482 - accuracy: 0.7096 - val_loss: 1.0128 - val_accuracy: 0.6444
# Epoch 10/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.7285 - accuracy: 0.7172 - val_loss: 1.0295 - val_accuracy: 0.6222
# Epoch 11/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.5943 - accuracy: 0.7803 - val_loss: 1.0526 - val_accuracy: 0.6000
# Epoch 12/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.4717 - accuracy: 0.8712 - val_loss: 1.1240 - val_accuracy: 0.5778
# Epoch 13/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.3949 - accuracy: 0.8712 - val_loss: 1.1091 - val_accuracy: 0.5778
# Epoch 14/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.3255 - accuracy: 0.8965 - val_loss: 0.9941 - val_accuracy: 0.6000
# Epoch 15/15
# 4/4 [==============================] - 30s 7s/step - loss: 0.2956 - accuracy: 0.8990 - val_loss: 0.9127 - val_accuracy: 0.6222

# %% [markdown]
# **Evaluate the Trained Model on Testing Data**

# %%
[test_loss, test_acc] = model.evaluate(test_images, test_labels)
print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss, test_acc*100))
# Out:
# 2/2 [==============================] - 1s 293ms/step - loss: 0.9127 - accuracy: 0.6222
# Evaluation result on Test Data : Loss = 0.912676215171814, accuracy = 62.22222447395325

# %% [markdown]
# **Save Trained Model**

# %%
model_path = '/content/drive/My Drive/ComputerVision_Shared/CNN_Code/'

model.save(model_path+'my_model.h5')

# %% [markdown]
# **Display Loss and Accuracy Plots**

# %%
#Plot the Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
plt.show()

#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
plt.show()

# %% [markdown]
# **Test the Trained Model on Testing Data: <br/>Testing a single image**

# %%
# Predict the most likely class
test_img_number = 7

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kane Williamson

# %%
# Predict the most likely class
test_img_number = 20

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Maria Sharapova

# %%
# Predict the most likely class
test_img_number = 15

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kane Williamson

# %%
# Predict the most likely class
test_img_number = 21

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Maria Sharapova

# %%
# Predict the most likely class
test_img_number = 34

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Ronaldo

# %%
# Predict the most likely class
test_img_number = 40

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kobe Bryant

# %%
# Predict the most likely class
test_img_number = 42

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kane Williamson

# %%
# Predict the most likely class
test_img_number = 43

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kane Williamson

# %%
# Predict the most likely class
test_img_number = 44

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kane Williamson

# %%
# Predict the most likely class
test_img_number = 30

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kane Williamson

# %%
# Predict the most likely class
test_img_number = 14

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Ronaldo

# %%
# Predict the most likely class
test_img_number = 29

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kobe Bryant

# %%
# Predict the most likely class
test_img_number = 32

prediction = inv_name_mapping_dict[np.argmax(model.predict(test_images[[test_img_number],:])[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(test_images[test_img_number])
plt.title("Ground Truth : {}".format(inv_name_mapping_dict[np.argmax(test_labels[test_img_number])]))
plt.show()
# Out:
# Model prediction: Kane Williamson
