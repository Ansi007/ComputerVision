# %%
>>> from urllib.request import urlopen

# %%
>>> url = "https://en.softonic.com/windows/security-privacy:free"

# %%
>>> page = urlopen(url)

# %%
>>> page

# %%
>>> html_bytes = page.read()
>>> html = html_bytes.decode("utf-8")

# %%
>>> print(html)
# Out:
# <!DOCTYPE html><html lang="en-US"><head><meta charset="utf-8"><meta http-equiv="x-ua-compatible" content="ie=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#0277bd"><meta property="og:ttl" content="2419200"><title>Download the Most Popular Free Security & Privacy for Windows | Softonic </title><meta name="title" content="Download the Most Popular Free Security &amp; Privacy for Windows | Softonic "><meta name="description" content="Download free Windows Security &amp; Privacy from Softonic. Safe and 100% virus-free. Discover Windows Security &amp; Privacy, tips, tutorials, videos, and mu"><meta name="keywords" content="Security &amp; Privacy, Software Security &amp; Privacy, Security &amp; Privacy, Windows"><meta name="robots" content="all"><link rel="canonical" href="https://en.softonic.com/windows/security-privacy:free"><meta name="webgains-site-verification" content="111b7815"><meta name="appMeasuringPerformance" content
# ...

# %%
>>> title_index = html.find('<h2>')
>>> title_index
# Out:
# 141223

# %%
>>> start_index = title_index + len("<h2>")
>>> start_index
# Out:
# 141227

# %%
>>> end_index = html.find("</h2>")
>>> end_index
# Out:
# 141247

# %%
>>> appName = html[start_index:end_index]
>>> appName
# Out:
# 'Avast Free Antivirus'

# %%
pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=c2690ffef68496b796e0ddf86f5d3de638eb0caab36eb9238ffb809976e0402a
#   Stored in directory: c:\users\anns\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Module
from bs4 import BeautifulSoup
import requests

# Website URL
URL = 'https://en.softonic.com/windows/security-privacy:free'

# class list set
class_list = set()

# Page content from Website URL
page = requests.get( URL )

# parse html content
soup = BeautifulSoup( html , 'html.parser')
header = soup.find_all('h2') 
print(header)
# Out:
# [<h2>Avast Free Antivirus</h2>, <h2>TotalAV Essential Antivirus</h2>, <h2>Psiphon</h2>, <h2>Hamachi</h2>, <h2>Free VPN</h2>, <h2>IPVanish</h2>, <h2>Radmin VPN</h2>, <h2>Windows Defender</h2>, <h2>VyprVPN for Windows</h2>, <h2>Tuxler</h2>, <h2>Windscribe</h2>, <h2>iTop VPN</h2>, <h2>Cisco AnyConnect Secure Mobility Client</h2>, <h2>SetupVPN - Lifetime Free VPN</h2>, <h2>Hotspot Shield</h2>, <h2>Vuze</h2>, <h2>Hola Unlimited Free VPN</h2>, <h2>XVPN</h2>, <h2>Urban VPN</h2>, <h2>Free KeyLogger</h2>, <h2 class="title-section mb-xs" data-meta="related-articles-title">Articles <span>about Security &amp; Privacy</span></h2>]
